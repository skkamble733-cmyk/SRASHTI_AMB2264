# %%
def fun(x):
   print(" local x is :",x)
   x=2
   print("changed local x to :",x)
x=50
fun(x)
print("x is still:",x)
# Out:
#  local x is : 50
# changed local x to : 2
# x is still: 50

# %%
def fun1 ():
 global y
 print("y is :",y)
 y=2
 print("changed y to :",y)
y=50
fun1()
print("value of y is :",y)
# Out:
# y is : 50
# changed y to : 2
# value of y is : 2

# %%
total=0
def sum(arg1,arg2):
    total=arg1+arg2
    print("inside the function local total:",total)
    return total
sum(10,20)
print("outside the function global total:",total)
# Out:
# inside the function local total: 30
# outside the function global total: 0

# %%
def printme (str1):
  print(str1)
  return
printme('hello')
printme("1234")
# Out:
# hello
# 1234

# %%
def printme(str):
    print(str)
    return
printme('hello')
printme(str='my string')
# Out:
# hello
# my string

# %%
def fun (a,b=5,c=10):
  print('a is :',a,'b is :',b,'c is:',c)
fun(3,7)
fun(25,b=24)
fun(c=60,a=79)
# Out:
# a is : 3 b is : 7 c is: 10
# a is : 25 b is : 24 c is: 10
# a is : 79 b is : 5 c is: 60

# %%
def check (name,*marks):
   print(name)
   print(marks)
check('xyz',10,20,30)
# Out:
# xyz
# (10, 20, 30)

# %%
def check (name,age==20):
  print(name)
  print(age)
check(name='x')
# Out:
#   File "/tmp/ipython-input-3588341833.py", line 1
#     def check (name,age==20):
#                        ^
# SyntaxError: invalid syntax
