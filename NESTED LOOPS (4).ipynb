# %%
r=float(input("enter radius of a circle"))
ch=int(input("enter 1 for area, 2 for perimeter"))
a=3.14*r*r
b=2*3.14*r
if ch==1:
  print("area of cirlce",a)
elif ch==2:
   print("perimeter of circle",b)
else:
  print("zero")
# Out:
# enter radius of a circle25
# enter 1 for area, 2 for perimeter1
# area of cirlce 1962.5

# %%
a=int(input("type a number"))
if(a%5==0 and a%7==0):
  print("a is divisble by 5 and 7")
else:
  print("a is not divisble by 5 and 7")
# Out:
# type a number23
# a is not divisble by 5 and 7

# %%
a=int(input("enter first number"))
b=int(input("enter second number"))
if(a>b):
  print("{} is greater between {} and {}".format(a,a,b))
elif(b>a):
  print("{} is greater between {} and {}".format(b,a,b))
else:
  print("{} and {} are equal".format(a,b))
# Out:
# enter first number5
# enter second number5
# 5 and 5 are equal

# %%
a=int(input("enter first number"))
b=int(input("enter second number"))
if ( a>b):
  print("{} is greater between{} and {}".format(a,a,b))
elif(b>a):
  print("{} is greater between{} and {}".format(b,a,b))
else:
  print("{} and {} are euqal".format(a,b))
# Out:
# enter first number23
# enter second number25
# 25 is greater between23 and 25

# %%
list1=[1,2,3.0,'hi',4]
print(list1)
print(len(list1))
print(list1.index(2))
list1.append('hi')
print(list1)
list1.insert(2,'hello')
list1
list1.reverse()
print(list1)
list1
print(list1.count('hi'))
print(list1.pop())
print(list1)
list1.pop(1)
print(list1)
list1.remove('hello')
print(list1)
list1.clear()
print(list1)
# Out:
# [1, 2, 3.0, 'hi', 4]
# 5
# 1
# [1, 2, 3.0, 'hi', 4, 'hi']
# ['hi', 4, 'hi', 3.0, 'hello', 2, 1]
# 2
# 1
# ['hi', 4, 'hi', 3.0, 'hello', 2]
# ['hi', 'hi', 3.0, 'hello', 2]
# ['hi', 'hi', 3.0, 2]
# []

# %%
list1=[2,30,4]
print(list1)
list1.sort()
print(list1)
print(max(list1))
print(min(list1))
# Out:
# [2, 30, 4]
# [2, 4, 30]
# 30
# 2

# %%
my_list=['a','H','e','h','A']
print(my_list)
# Out:
# ['a', 'H', 'e', 'h', 'A']

# %%
a=[12,24,36]
b=a.copy()
print("a",a)
print("b",b)
b.insert(1,55)
print("a:",a)
print("b:",b)
# Out:
# a [12, 24, 36]
# b [12, 24, 36]
# a: [12, 24, 36]
# b: [12, 55, 24, 36]
