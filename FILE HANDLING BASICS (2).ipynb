# %%
file=open("abc.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# /tmp/ipython-input-2367381362.py in <cell line: 0>()
#       1 file=open("abc.txt","a")
# ----> 2 content=file.read()
#       3 print(content)
#       4 file.close()
#
# UnsupportedOperation: not readable

# %%
file=open("abc.txt","w")
file.write("Hello GKVK")
file.close()

# %%
file=open("abc.txt","r")
print(file.read())
file.close()
# Out:
# Hello GKVK

# %%
file=open("y.txt","a")
file.write("how are you")
file.close()
file=open("y.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# how are youhow are youhow are youhow are youhow are youhow are you

# %%
try:
  file=open("xyz.txt","r")
  print(file.read())
  file.close()
except:
  print("no such file")
# Out:
# how are youhow are youhow are youhow are youhow are youhow are you

# %%
def my_function():
  print("hello")
print(my_function())
# Out:
# hello
# None

# %%
def my_function():
  print("hello latha")
print(my_function())
# Out:
# hello latha
# None

# %%
try:
  a=10
  b=20
  c=a+b
  print(c)
except:
  print("error")
# Out:
# 30

# %%
def Myfunction():
  print("hello")
myfunction()
# Out:
# hello

# %%
def expt(a,b):
    c=a/b
    print(c)
a=2
b=4
expt(a,b)
# Out:
# 0.5

# %%
def expr(a,b):
  try:
    c=a/b
    print(c)
  except ZeroDivisionError:
    print("error")
a=2
b=1
expr(a,b)
# Out:
# 2.0

# %%
def my_fun():
  pass
my_fun()
