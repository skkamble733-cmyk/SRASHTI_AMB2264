# %%
print(2+3)
# Out:
# 5

# %%
print(6-4)
# Out:
# 2

# %%
print(2*5)
# Out:
# 10

# %%
print(15/3)
# Out:
# 5.0

# %%
print(2+3*4/8)
# Out:
# 3.5

# %%
print(3//2)
# Out:
# 1

# %%
print(3%2)
# Out:
# 1

# %%
subject="AIML"
print(subject)
# Out:
# AIML

# %%
subject='AIML'
print(subject)
# Out:
# AIML

# %%
subject='bioagent'
print(subject)
# Out:
# bioagent

# %%
x=10
y=20
z=x+y
print(z)
# Out:
# 30

# %%
x=32
y=32
z=x*y
print(z)
# Out:
# 1024

# %%
w=7
x=7
y=7
z=x*y*w
print(z)
# Out:
# 343

# %%
str1="gkvk"
str2="agriculture"
str3=str1+" "+str2
print(str3)
# Out:
# gkvk agriculture

# %%
str1="gkvk"
str2="agriculture"
str3=str1+" classfor "+str2
print(str3)
# Out:
# gkvk classfor agriculture

# %%
str="gkvk"+" "
print(str*10)
# Out:
# gkvk gkvk gkvk gkvk gkvk gkvk gkvk gkvk gkvk gkvk

# %%
a=b=c=10
print(a)
print(b)
print(c)
# Out:
# 10
# 10
# 10

# %%
a=b=c=10
print(a*b*c)
# Out:
# 1000

# %%
a=b=c=2
print(a+b-c)
# Out:
# 2

# %%
_9a=10
print(_9a+10)
# Out:
# 20

# %%
_9a=10
print(_9a)
# Out:
# 10
