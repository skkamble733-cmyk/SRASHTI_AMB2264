# %%
s='banana'
s.upper()
# Out:
# 'BANANA'

# %%
s='banana'
s.capitalize()
# Out:
# 'Banana'

# %%
greet='hello morning'
s1=greet.replace('hello','good')
print(s1)
print(greet)
# Out:
# good morning
# hello morning

# %%
greet='  hello morning  '
s1=greet.strip()
print(greet)
print('Both ends')
print(s1)
# Out:
#   hello morning
# Both ends
# hello morning

# %%
greet='  hello morning'
s1=greet.lstrip()
print(greet)
print('only from one side')
print(s1)
# Out:
#   hello morning
# only from one side
# hello morning

# %%
greet='hello morning  '
s1=greet.rstrip()
print(greet)
print('only from one side')
print(s1)
print(len(s1))
# Out:
# hello morning
# only from one side
# hello morning
# 13

# %%
greet='hello morning'
print(greet.split('e'))
# Out:
# ['h', 'llo morning']

# %%
str1='hello'
str2='*:*:*'.join(str1)
print(str2)
print(str1)
# Out:
# h*:*:*e*:*:*l*:*:*l*:*:*o
# hello

# %%
a='this is a string'
b=a.split(' ')
print(a)
print(b)
# Out:
# this is a string
# ['this', 'is', 'a', 'string']

# %%
str1='python'
slen=len(str1)
rev=str1[slen::-1]
print(rev)
# Out:
# nohtyp

# %%
rev=''.join(reversed(str1))
print(rev)
print(str1)
# Out:
# olleh
# hello
