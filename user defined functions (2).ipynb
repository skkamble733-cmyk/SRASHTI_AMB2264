# %% [markdown]
# **AMB2264_ Srashti_user defined functions**

# %% [markdown]
# **user-defined functions**

# %%
soil_moisture=[45,60,30,55,40]
print("soil moisture levels in diffrent fileds")
for moisture in soil_moisture:
 print(moisture,"%")
# Out:
# soil moisture levels in diffrent fileds
# 45 %
# 60 %
# 30 %
# 55 %
# 40 %

# %%
print(" fields that needed irrigation")
for moisture in soil_moisture:
  if (moisture <50 ) :
    print(moisture,"%-irrigaton needed")
  else:
    print(moisture,"%-sufficient moisture")
# Out:
#  fields that needed irrigation
# 45 %-irrigaton needed
# 60 %-sufficient moisture
# 30 %-irrigaton needed
# 55 %-sufficient moisture
# 40 %-irrigaton needed
