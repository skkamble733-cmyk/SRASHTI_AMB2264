# %%
dict={'rice':120,'wheat':85,'maize':60}
print("total elements..>",len(dict))
# Out:
# total elements..> 3

# %%
print("yield of wheat..>",dict['wheat'])
# Out:
# yield of wheat..> 85

# %%
dict['pulses']=45
print("after addind('pulses')..>",dict)
# Out:
# after addind('pulses')..> {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}

# %%
dict['rice']=130
print("after updating('rice')..>",dict)
# Out:
# after updating('rice')..> {'rice': 130, 'wheat': 85, 'maize': 60, 'pulses': 45}

# %%
print("keys..>",dict.keys())
# Out:
# keys..> dict_keys(['rice', 'wheat', 'maize', 'pulses'])

# %%
print("values..>",dict.values())
# Out:
# values..> dict_values([130, 85, 60, 45])

# %%
print("is key 'sugarcane' present", 'sugarcane' in dict.keys())
# Out:
# is key 'sugarcane' present False

# %%
dict={'rice': 130, 'wheat': 85, 'maize': 60, 'pulses': 45}
print('sum',sum(dict.values()))
dict['wheat']+=10
print("after adding 10 to the 'wheat'",dict)
# Out:
# sum 320
# after adding 10 to the 'wheat' {'rice': 130, 'wheat': 95, 'maize': 60, 'pulses': 45}

# %%
keys=['rice','wheat','maize','pulses']
values=[130,95,60,45]
mdict={}
for i in range(len(keys)):
    mdict[keys[i]]=values[i]
print(mdict)
# Out:
# {'rice': 130, 'wheat': 95, 'maize': 60, 'pulses': 45}

# %%
dict2=dict.copy()
print(dict2)
print(dict)
# Out:
# {'rice': 130, 'wheat': 95, 'maize': 60, 'pulses': 45}
# {'rice': 130, 'wheat': 95, 'maize': 60, 'pulses': 45}

# %%
print("values..>",dict2.values())
# Out:
# values..> dict_values([130, 95, 60, 45])

# %%
dict2.clear()
print("dict2 after clear..>",dict2)
# Out:
# dict2 after clear..> {}

# %%
keys=["rice","wheat","maize","pulses"]
values=[130,95,60,45]
print(dict(zip(keys,values)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3101724203.py in <cell line: 0>()
#       1 keys=["rice","wheat","maize","pulses"]
#       2 values=[130,95,60,45]
# ----> 3 print(dict(zip(keys,values)))
#
# TypeError: 'dict' object is not callable

# %%
print("jowar yield..>",dict.get("jowar","not cultivated"))
# Out:
# jowar yield..> not cultivated

# %%
dict={'rice': 130, 'wheat': 95, 'maize': 60, 'pulses': 45}
del dict['maize']
print(dict)
print(dict.keys['maize'])
# Out:
# {'rice': 130, 'wheat': 95, 'pulses': 45}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2575626741.py in <cell line: 0>()
#       2 del dict['maize']
#       3 print(dict)
# ----> 4 print(dict.keys['maize'])
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
print(dict.keys('maize'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2040948011.py in <cell line: 0>()
# ----> 1 print(dict.keys('maize'))
#
# TypeError: dict.keys() takes no arguments (1 given)

# %%
t=('pratham','sharma',3.14,3)
print('t  ..>',t)
print('number of elements  ..>',len(t))
print('type of the object ..>',type(t))
# Out:
# t  ..> ('pratham', 'sharma', 3.14, 3)
# number of elements  ..> 4
# type of the object ..> <class 'tuple'>

# %%
t=('book')
print(type(t))
# Out:
# <class 'str'>

# %%
t=('book',)
print(type(t))
# Out:
# <class 'tuple'>

# %%
t=('pratham','sharma',3.14,3)
print('t..>',t)
i=0
print('')
while i<len(t):
  print(i)
  i+=1
# Out:
# t..> ('pratham', 'sharma', 3.14, 3)
#
# 0
# 1
# 2
# 3

# %%
t=('pratham','sharma',3.14,3)
print('t..>',t)
print('')
for i in range(len(t)):
  print(t[i])
# Out:
# t..> ('pratham', 'sharma', 3.14, 3)
#
# pratham
# sharma
# 3.14
# 3
